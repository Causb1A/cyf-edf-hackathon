# %%
from google.colab import files
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#import data file
files.upload()
# Out:
#      <input type="file" id="files-40171bd5-0d99-4294-82f1-3c03458ea772" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-40171bd5-0d99-4294-82f1-3c03458ea772">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving googleplaystore.csv to googleplaystore.csv
# {'googleplaystore.csv': b'App,Category,Rating,Reviews,Size,Installs,Type,Price,Content Rating,Genres,Last Updated,Current Ver,Android Ver\r\nPhoto Editor & Candy Camera & Grid & ScrapBook,ART_AND_DESIGN,4.1,159,19M,"10,000+",Free,0,Everyone,Art & Design,"January 7, 2018",1.0.0,4.0.3 and up\r\nColoring book moana,ART_AND_DESIGN,3.9,967,14M,"500,000+",Free,0,Everyone,Art & Design;Pretend Play,"January 15, 2018",2.0.0,4.0.3 and up\r\n"U Launcher Lite \xe2\x80\x93 FREE Live Cool Themes, Hide Apps",ART_AND_DESIGN,4.7,87510,8.7M,"5,000,000+",Free,0,Everyone,Art & Design,"August 1, 2018",1.2.4,4.0.3 and up\r\nSketch - Draw & Paint,ART_AND_DESIGN,4.5,215644,25M,"50,000,000+",Free,0,Teen,Art & Design,"June 8, 2018",Varies with device,4.2 and up\r\nPixel Draw - Number Art Coloring Book,ART_AND_DESIGN,4.3,967,2.8M,"100,000+",Free,0,Everyone,Art & Design;Creativity,"June 20, 2018",1.1,4.4 and up\r\nPaper flowers instructions,ART_AND_DESIGN,4.4,167,5.6M,"50,000+",Free,0,Everyone,Art & Design,"March 26, 2017",1.0,2.3 and up\r\nSmoke Effect Photo Maker - Smoke Editor,ART_AND_DESIGN,3.8,178,19M,"50,000+",Free,0,Everyone,Art & Design,"April 26, 2018",1.1,4.0.3 and up\r\nInfinite Painter,ART_AND_DESIGN,4.1,36815,29M,"1,000,000+",Free,0,Everyone,Art & Design,"June 14, 2018",6.1.61.1,4.2 and up\r\nGarden Coloring Book,ART_AND_DESIGN,4.4,13791,33M,"1,000,000+",Free,0,Everyone,Art & Design,"September 20, 2017",2.9.2,3.0 and up\r\nKids Paint Free - Drawing Fun,ART_AND_DESIGN,4.7,121,3.1M,"10,000+",Free,0,Everyone,Art & Design;Creativity,"July 3, 2018",2.8,4.0.3 and up\r\nText on Photo - Fonteee,ART_AND_DESIGN,4.4,13880,28M,"1,000,000+",Free,0,Everyone,Art & Design,"October 27, 2017",1.0.4,4.1 and up\r\nName Art Photo Editor - Focus n Filters,ART_AND_DESIGN,4.4,8788,12M,"1,000,000+",Free,0,Everyone,Art & Design,"July 31, 2018",1.0.15,4.0 and up\r\nTattoo Name On My Photo Editor,ART_AND_DESIGN,4.2,44829,20M,"10,000,000+",Free,0,Teen,Art & Design,"April 2, 2018",3.8,4.1 and up\r\nMandala Coloring Book,ART_AND_DESIGN,4.6,4326,21M,"100,000+",Free,0,Everyone,Art & Design,"June 26, 2018",1.0.4,4.4 and up\r\n3D Color Pixel by Number - Sandbox Art Coloring,ART_AND_DESIGN,4.4,1518,37M,"100,000+",Free,0,Everyone,Art & Design,"August 3, 2018",1.2.3,2.3 and up\r\nLearn To Draw Kawaii Characters,ART_AND_DESIGN,3.2,55,2.7M,"5,000+",Free,0,Everyone,Art & Design,"June 6, 2018",NaN,4.2 and up\r\nPhoto Designer - Write your name with shapes,ART_AND_DESIGN,4.7,3632,5.5M,"500,000+",Free,0,Everyone,Art & Design,"July 31, 2018",3.1,4.1 and up\r\n350 Diy Room Decor Ideas,ART_AND_DESIGN,4.5,27,17M,"10,000+",Free,0,Everyone,Art & Design,"November 7, 2017",1.0,2.3 and up\r\nFlipaClip - Cartoon animation,ART_AND_DESIGN,4.3,194216,39M,"5,000,000+",Free,0,Everyone,Art & Design,"August 3, 2018",2.2.5,4.0.3 and up\r\nibis Paint X,ART_AND_DESIGN,4.6,224399,31M,"10,000,000+",Free,0,Everyone,Art & Design,"July 30, 2018",5.5.4,4.1 and up\r\nLogo Maker - Small Business,ART_AND_DESIGN,4.0,450,14M,"100,000+",Free,0,Everyone,Art & Design,"April 20, 2018",4.0,4.1 and up\r\nBoys Photo Editor - Six Pack & Men\'s Suit,ART_AND_DESIGN,4.1,654,12M,"100,000+",Free,0,Everyone,Art & Design,"March 20, 2018",1.1,4.0.3 and up\r\nSuperheroes Wallpapers | 4K Backgrounds,ART_AND_DESIGN,4.7,7699,4.2M,"500,000+",Free,0,Everyone 10+,Art & Design,"July 12, 2018",2.2.6.2,4.0.3 and up\r\nMcqueen Coloring pages,ART_AND_DESIGN,NaN,61,7.0M,"100,000+",Free,0,Everyone,Art & Design;Action & Adventure,"March 7, 2018",1.0.0,4.1 and up\r\nHD Mickey Minnie Wallpapers,ART_AND_DESIGN,4.7,118,23M,"50,000+",Free,0,Everyone,Art & Design,"July 7, 2018",1.1.3,4.1 and up\r\nHarley Quinn wallpapers HD,ART_AND_DESIGN,4.8,192,6.0M,"10,000+",Free,0,Everyone,Art & Design,"April 25, 2018",1.5,3.0 and up\r\nColorfit - Drawing & Coloring,ART_AND_DESIGN,4.7,20260,25M,"500,000+",Free,0,Everyone,Art & Design;Creativity,"October 11, 2017",1.0.8,4.0.3 and up\r\nAnimated Photo Editor,ART_AND_DESIGN,4.1,203,6.1M,"100,000+",Free,0,Everyone,Art ...

# %%
# Load example dataset
google_playstore_data = pd.read_csv('/content/googleplaystore.csv')

# %%
google_playstore_data
# Out:
#                                                      App  ...         Android Ver
# 0         Photo Editor & Candy Camera & Grid & ScrapBook  ...        4.0.3 and up
# 1                                    Coloring book moana  ...        4.0.3 and up
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...  ...        4.0.3 and up
# 3                                  Sketch - Draw & Paint  ...          4.2 and up
# 4                  Pixel Draw - Number Art Coloring Book  ...          4.4 and up
# ...                                                  ...  ...                 ...
# 10836                                   Sya9a Maroc - FR  ...          4.1 and up
# 10837                   Fr. Mike Schmitz Audio Teachings  ...          4.1 and up
# 10838                             Parkinson Exercices FR  ...          2.2 and up
# 10839                      The SCP Foundation DB fr nn5n  ...  Varies with device
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology  ...  Varies with device
#
# [10841 rows x 13 columns]

# %%
# Inspect the data types of the example dataset
google_playstore_data.dtypes

# %%
# Load practice dataset
energy_performance_data = pd.read_csv('/content/energy_cat.csv')

# %%
energy_performance_data
# Out:
#      Relative Compactness  Surface Area  ...  Cooling Load  surface_area_categories
# 0                    0.98         514.5  ...         21.33    Very Low Surface Area
# 1                    0.98         514.5  ...         21.33    Very Low Surface Area
# 2                    0.98         514.5  ...         21.33    Very Low Surface Area
# 3                    0.98         514.5  ...         21.33    Very Low Surface Area
# 4                    0.90         563.5  ...         28.28    Very Low Surface Area
# ..                    ...           ...  ...           ...                      ...
# 763                  0.64         784.0  ...         21.40   Very High Surface Area
# 764                  0.62         808.5  ...         16.88   Very High Surface Area
# 765                  0.62         808.5  ...         17.11   Very High Surface Area
# 766                  0.62         808.5  ...         16.61   Very High Surface Area
# 767                  0.62         808.5  ...         16.03   Very High Surface Area
#
# [768 rows x 11 columns]

# %%
# Plot a histogram in seaborn
sns.histplot(data=google_playstore_data, x="Rating", binwidth=0.5)

# %%
# Create a density plot for the ratings received by apps belonging to 5 categories
select_categories = google_playstore_data[google_playstore_data['Category'].isin(['ART_AND_DESIGN', 'EDUCATION', 'DATING', 'WEATHER', 'FINANCE'])]
sns.displot(data=select_categories, x="Rating", hue ='Category', kind="kde", fill = True)

# %%
# Create a scatterplot of ratings vs reviews for art and design apps
art_and_design_apps = google_playstore_data[google_playstore_data['Category'].isin(['ART_AND_DESIGN'])]
art_and_design_apps["Reviews"] = art_and_design_apps["Reviews"].astype(int)
art_and_design_apps= art_and_design_apps[art_and_design_apps["Reviews"]<=10000]
sns.scatterplot(data=art_and_design_apps, x="Reviews", y="Rating")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Create a boxplot to show the distribution of ratings for apps belonging to five selected categories
sns.boxplot(x="Category", y="Rating", data=select_categories)

# %%
# Create a violin plot and compare with the box-plot from above
sns.violinplot(x="Category", y="Rating", data=select_categories)

# %%
# Create a bar-plot to show the average rating received by apps in each of a few selected categories
select_categories_average_rating  = select_categories.groupby(by =['Category']).mean().reset_index()
ax=sns.barplot(x="Category", y="Rating", data=select_categories_average_rating)
