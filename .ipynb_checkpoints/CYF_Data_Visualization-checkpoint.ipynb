# %%
from google.colab import files
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-47164b23025b> in <module>
# ----> 1 from google.colab import files
#       2 import pandas as pd
#       3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
#import data file
files.upload()
# Out:
#      <input type="file" id="files-14f34ba5-80a7-4ce0-a0c9-a7257a734ae7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-14f34ba5-80a7-4ce0-a0c9-a7257a734ae7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving energy.csv to energy.csv
# {'energy.csv': b'Relative Compactness,Roof Area,Overall Height,Orientation,Glazing Area,Glazing Area Distribution,Heating Load,Cooling Load,Location,Glazing Area Distribution Original,surface_area_categories,wall_description\r\n0.71,220.5,3.5,5,0.1,4.407174601,10.72,14.2,Mountain,4,High Surface Area,The wall colour is yellow and the area is 269.5 meter squared.\r\n0.62,220.5,3.5,3,0.1,3.725391577,12.74,13.97,City,5,Very High Surface Area,The wall colour is violet and the area is 367.5 meter squared.\r\n0.82,147,7,4,0.25,1.530089721,25.38,26.72,Countryside,2,Low Surface Area,The wall colour is violet and the area is 318.5 meter squared.\r\n0.74,220.5,3.5,5,0.25,2.007143957,12.3,15.44,City,2,Average Surface Area,The wall colour is blue and the area is 245.0 meter squared.\r\n0.76,122.5,7,5,0.4,1.6498515,40.43,39.48,Seaside,1,Average Surface Area,The wall colour is violet and the area is 416.5 meter squared.\r\n0.86,147,7,5,0.25,4.158053639,29.07,29.82,Seaside,3,Low Surface Area,The wall colour is green and the area is 294.0 meter squared.\r\n0.64,220.5,3.5,3,0.1,4.20423973,15.19,19.25,Lakeside,4,Very High Surface Area,The wall colour is green and the area is 343.0 meter squared.\r\n0.64,220.5,3.5,4,0.4,2.509557215,18.48,21.54,Seaside,3,Very High Surface Area,The wall colour is red and the area is 343.0 meter squared.\r\n0.66,220.5,3.5,4,0.4,3.191213766,14.92,17.55,City,5,Very High Surface Area,The wall colour is violet and the area is 318.5 meter squared.\r\n0.79,147,7,4,0.1,3.739128785,36.97,35.1,City,3,Average Surface Area,The wall colour is white and the area is 343.0 meter squared.\r\n0.98,110.25,7,4,0.1,4.837975889,24.04,26.18,Countryside,4,Very Low Surface Area,The wall colour is red and the area is 294.0 meter squared.\r\n0.64,220.5,3.5,3,0.25,3.585807575,16.84,20.56,Lakeside,2,Very High Surface Area,The wall colour is violet and the area is 343.0 meter squared.\r\n0.69,220.5,3.5,4,0.1,3.733432059,11.07,14.42,Mountain,4,High Surface Area,The wall colour is violet and the area is 294.0 meter squared.\r\n0.98,110.25,7,3,0.25,2.337283355,28.56,29.78,Countryside,3,Very Low Surface Area,The wall colour is blue and the area is 294.0 meter squared.\r\n0.74,220.5,3.5,2,0.1,3.530760009,10.08,13.2,Lakeside,4,Average Surface Area,The wall colour is green and the area is 245.0 meter squared.\r\n0.62,220.5,3.5,2,0.1,2.70990048,12.88,14.37,Countryside,2,Very High Surface Area,The wall colour is white and the area is 367.5 meter squared.\r\n0.82,147,7,5,0.4,2.607541849,29.52,28.43,City,4,Low Surface Area,The wall colour is yellow and the area is 318.5 meter squared.\r\n0.64,220.5,3.5,2,0.25,4.616225319,16.73,20.13,City,5,Very High Surface Area,The wall colour is yellow and the area is 343.0 meter squared.\r\n0.98,110.25,7,3,0.4,5.312922867,32.72,33.23,Countryside,5,Very Low Surface Area,The wall colour is violet and the area is 294.0 meter squared.\r\n0.64,220.5,3.5,3,0.1,3.643490379,15.36,19.18,City,3,Very High Surface Area,The wall colour is white and the area is 343.0 meter squared.\r\n0.74,220.5,3.5,5,0.4,1.847180521,13.78,16.6,Countryside,3,Average Surface Area,The wall colour is green and the area is 245.0 meter squared.\r\n0.64,220.5,3.5,5,0.4,2.664043597,19.12,21.93,City,2,Very High Surface Area,The wall colour is blue and the area is 343.0 meter squared.\r\n0.71,220.5,3.5,4,0.4,2.970830269,12.76,15.33,City,5,High Surface Area,The wall colour is yellow and the area is 269.5 meter squared.\r\n0.69,220.5,3.5,2,0.4,1.231397432,14.32,16.35,Countryside,3,High Surface Area,The wall colour is green and the area is 294.0 meter squared.\r\n0.9,122.5,7,3,0.1,6.267023158,29.08,29.52,Lakeside,5,Very Low Surface Area,The wall colour is violet and the area is 318.5 meter squared.\r\n0.62,220.5,3.5,2,0.25,1.838048567,14.34,15.32,Countryside,2,Very High Surface Area,The wall colour is orange and the area is 367.5 meter squared.\r\n0.64,220.5,3.5,2,0.4,0.244057514,18.48,20.78,City,3,Very High Surface Area,The wall colour is indigo and the area i ...

# %%
# Load example dataset
google_playstore_data = pd.read_csv('/content/googleplaystore.csv')

# %%
google_playstore_data
# Out:
#                                                      App  ...         Android Ver
# 0         Photo Editor & Candy Camera & Grid & ScrapBook  ...        4.0.3 and up
# 1                                    Coloring book moana  ...        4.0.3 and up
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...  ...        4.0.3 and up
# 3                                  Sketch - Draw & Paint  ...          4.2 and up
# 4                  Pixel Draw - Number Art Coloring Book  ...          4.4 and up
# ...                                                  ...  ...                 ...
# 10836                                   Sya9a Maroc - FR  ...          4.1 and up
# 10837                   Fr. Mike Schmitz Audio Teachings  ...          4.1 and up
# 10838                             Parkinson Exercices FR  ...          2.2 and up
# 10839                      The SCP Foundation DB fr nn5n  ...  Varies with device
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology  ...  Varies with device
#
# [10841 rows x 13 columns]

# %%
# Inspect the data types of the example dataset
google_playstore_data.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
# Load practice dataset
energy_performance_data = pd.read_csv('/content/energy.csv')

# %%
energy_performance_data
# Out:
#      Relative Compactness  ...                                   wall_description
# 0                    0.71  ...  The wall colour is yellow and the area is 269....
# 1                    0.62  ...  The wall colour is violet and the area is 367....
# 2                    0.82  ...  The wall colour is violet and the area is 318....
# 3                    0.74  ...  The wall colour is blue and the area is 245.0 ...
# 4                    0.76  ...  The wall colour is violet and the area is 416....
# ..                    ...  ...                                                ...
# 533                  0.79  ...  The wall colour is yellow and the area is 343....
# 534                  0.82  ...  The wall colour is orange and the area is 318....
# 535                  0.79  ...  The wall colour is white and the area is 343.0...
# 536                  0.66  ...  The wall colour is blue and the area is 318.5 ...
# 537                  0.82  ...  The wall colour is yellow and the area is 318....
#
# [538 rows x 12 columns]

# %% [markdown]
# ## View distributions of variables by creating histograms and density plots

# %%
# Plot a histogram in seaborn
sns.histplot(data=google_playstore_data, x="Rating", binwidth=0.5)

# %% [markdown]
# Practice: Examine the distribution of Roof Area using a histogram

# %%
sns.histplot(data=energy_performance_data[energy_performance_data["Roof Area"] < 1500], x="Roof Area", binwidth=10)

# %%
# Create a density plot for the ratings received by apps belonging to 5 categories
select_categories = google_playstore_data[google_playstore_data['Category'].isin(['ART_AND_DESIGN', 'EDUCATION', 'DATING', 'WEATHER', 'FINANCE'])]
sns.displot(data=select_categories, x="Rating", hue ='Category', kind="kde", fill = True)

# %% [markdown]
# ### Practice: Examine the distribution of Glazing Area Distribution for houses located in mountainous regions

# %%
select_locations = energy_performance_data[energy_performance_data['Location'] == "Mountain"]
sns.displot(data=select_locations, x="Glazing Area Distribution", kind="kde", fill = True)

# %% [markdown]
# ## Explore the relationship between numerical variables using scatterplots

# %%
# Create a scatterplot of ratings vs reviews for art and design apps
art_and_design_apps = google_playstore_data[google_playstore_data['Category'].isin(['ART_AND_DESIGN'])]
art_and_design_apps["Reviews"] = art_and_design_apps["Reviews"].astype(int)
art_and_design_apps= art_and_design_apps[art_and_design_apps["Reviews"]<=10000]
sns.scatterplot(data=art_and_design_apps, x="Reviews", y="Rating")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# ### Practice: Create multiple scatterplots between Heating Load/Cooling Load and the other numerical variables in the dataset

# %% [markdown]
# Hint: Use `seaborn.pairplot` : https://seaborn.pydata.org/generated/seaborn.pairplot.html

# %%
sns.pairplot(
    energy_performance_data,
    x_vars=['Relative Compactness', 'Roof Area', 'Overall Height', 'Orientation',
       'Glazing Area', 'Glazing Area Distribution'],
    y_vars=['Heating Load', 'Cooling Load'],
)

# %% [markdown]
# ## Explore the relationship between numerical and categorical variables using box-plots or violin plots

# %%
# Create a boxplot to show the distribution of ratings for apps belonging to five selected categories
sns.boxplot(x="Category", y="Rating", data=select_categories)

# %%
# Create a violin plot and compare with the box-plot from above
sns.violinplot(x="Category", y="Rating", data=select_categories)

# %% [markdown]
# ### Practice: Create box or violin plots to show the distribution of 'Heating Load' for houses in different locations

# %%
# View the different location categories in the energy performance data
energy_performance_data['Location'].unique()
# Out:
# array(['Mountain', 'City', 'Countryside', 'Seaside', 'Lakeside', nan,
#        '77'], dtype=object)

# %%
# Filter out rows with location = nan or 77
data_for_violin_plot = energy_performance_data[(energy_performance_data['Location'] != '77') & (energy_performance_data['Location'].notnull())]

# %%
sns.violinplot(x="Location", y="Heating Load", data=data_for_violin_plot)

# %% [markdown]
# ## Create bar plot to display summary statistics for different categories

# %%
# Create a bar-plot to show the average rating received by apps in each of a few selected categories
select_categories_average_rating  = select_categories.groupby(by =['Category']).mean().reset_index()
ax=sns.barplot(x="Category", y="Rating", data=select_categories_average_rating)

# %% [markdown]
# ### Practice: Create a bar plot to display the average cooling load for houses in different locations

# %%
# Create a bar-plot to show the average rating received by apps in each of a few selected categories
location_coolingL_average_rating  = data_for_violin_plot.groupby(by =['Location']).mean().reset_index()
ax=sns.barplot(x="Location", y="Cooling Load", data=location_coolingL_average_rating)

# %%
# Correlation heatmap to explore correlation between variables in the energy perfromance dataset
sns.heatmap(energy_performance_data.corr())
